# %%
try:
    from pytorch_tabnet.tab_model import TabNetClassifier
    print("TabNet OK")
except Exception as e:
    print("TabNet import failed:", e)

try:
    from tabpfn import TabPFNClassifier
    print("TabPFN OK")
except Exception as e:
    print("TabPFN import failed:", e)
# Out:
# TabNet import failed: No module named 'pytorch_tabnet'
# TabPFN import failed: No module named 'tabpfn'

# %%
# !pip install -U -r requirements.txt
# Out:
# Requirement already satisfied: jupytext>=1.16 in /home/ppanta/.local/lib/python3.10/site-packages (from -r requirements.txt (line 2)) (1.17.3)
# Requirement already satisfied: nbformat>=5.9 in /home/ppanta/.local/lib/python3.10/site-packages (from -r requirements.txt (line 5)) (5.10.4)
# Requirement already satisfied: nbconvert>=7.10 in /home/ppanta/.local/lib/python3.10/site-packages (from -r requirements.txt (line 6)) (7.16.6)
# Requirement already satisfied: ipykernel>=6.29 in /home/ppanta/.local/lib/python3.10/site-packages (from -r requirements.txt (line 7)) (6.30.1)
# Requirement already satisfied: jupyterlab>=4.2 in /home/ppanta/.local/lib/python3.10/site-packages (from -r requirements.txt (line 10)) (4.4.9)
# Requirement already satisfied: import-ipynb in ./lib/python3.10/site-packages (from -r requirements.txt (line 13)) (0.2)
# Requirement already satisfied: pandas>=2.2 in ./lib/python3.10/site-packages (from -r requirements.txt (line 16)) (2.3.3)
# Requirement already satisfied: numpy>=1.26 in ./lib/python3.10/site-packages (from -r requirements.txt (line 17)) (2.2.6)
# Requirement already satisfied: scipy>=1.11 in ./lib/python3.10/site-packages (from -r requirements.txt (line 18)) (1.15.3)
# Requirement already satisfied: matplotlib>=3.8 in ./lib/python3.10/site-packages (from -r requirements.txt (line 21)) (3.10.6)
# Requirement already satisfied: seaborn>=0.13 in ./lib/python3.10/site-packages (from -r requirements.txt (line 22)) (0.13.2)
# Requirement already satisfied: scikit-learn>=1.5 in ./lib/python3.10/site-packages (from -r requirements.txt (line 25)) (1.7.2)
# Requirement already satisfied: imbalanced-learn>=0.12 in ./lib/python3.10/site-packages (from -r requirements.txt (line 26)) (0.14.0)
# Requirement already satisfied: xgboost>=2.0 in ./lib/python3.10/site-packages (from -r requirements.txt (line 27)) (3.0.5)
# Requirement already satisfied: catboost>=1.2 in ./lib/python3.10/site-packages (from -r requirements.txt (line 28)) (1.2.8)
# Requirement already satisfied: shap>=0.43 in ./lib/python3.10/site-packages (from -r requirements.txt (line 29)) (0.48.0)
# Collecting pytorch-tabnet>=4.1.0 (from -r requirements.txt (line 32))
#   Downloading pytorch_tabnet-4.1.0-py3-none-any.whl.metadata (15 kB)
# Collecting tabpfn>=0.1.10 (from -r requirements.txt (line 33))
#   Downloading tabpfn-2.2.1-py3-none-any.whl.metadata (29 kB)
# Collecting torch>=2.2 (from -r requirements.txt (line 37))
#   Downloading torch-2.6.0-cp310-cp310-manylinux1_x86_64.whl.metadata (28 kB)
# Collecting torchvision>=0.17 (from -r requirements.txt (line 38))
#   Downloading torchvision-0.21.0-cp310-cp310-manylinux1_x86_64.whl.metadata (6.1 kB)
# Requirement already satisfied: tabulate>=0.9 in ./lib/python3.10/site-packages (from -r requirements.txt (line 41)) (0.9.0)
# Requirement already satisfied: nvidia-ml-py3 in ./lib/python3.10/site-packages (from -r requirements.txt (line 44)) (7.352.0)
# Requirement already satisfied: scikit-learn-intelex in ./lib/python3.10/site-packages (from -r requirements.txt (line 47)) (2024.7.0)
# Requirement already satisfied: markdown-it-py>=1.0 in /home/ppanta/.local/lib/python3.10/site-packages (from jupytext>=1.16->-r requirements.txt (line 2)) (4.0.0)
# Requirement already satisfied: mdit-py-plugins in /home/ppanta/.local/lib/python3.10/site-packages (from jupytext>=1.16->-r requirements.txt (line 2)) (0.5.0)
# Requirement already satisfied: packaging in /home/ppanta/.local/lib/python3.10/site-packages (from jupytext>=1.16->-r requirements.txt (line 2)) (25.0)
# Requirement already satisfied: pyyaml in /home/ppanta/.local/lib/python3.10/site-packages (from jupytext>=1.16->-r requirements.txt (line 2)) (6.0.3)
# Requirement already satisfied: tomli in /home/ppanta/.local/lib/python3.10/site-packages (from jupytext>=1.16->-r requirements.txt (line 2)) (2.2.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /home/ppanta/.local/lib/python3.10/site-packages (from nbformat>=5.9->-r requirements.txt (line 5)) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /home/ppanta/.local/lib/python3.10/site-packages (from nbformat>=5.9->-r requirements.txt (line 5)) (4.25.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/ppanta/.local/lib/python3.10/site-packages (from nbformat>=5.9->-r requirements.txt (line 5)) (5.8.1)
# Requirement already satisfied: traitlets>=5.1 in /home/ppanta/.local/lib/python3.10/site-packages (from nbformat>=5.9->-r requirements.txt (line 5)) (5.14.3)
# Requirement already satisfied: beautifulsoup4 in /home/ppanta/.local/lib/python3.10/site-packages (from nbconvert>=7.10->-r requirements.txt (line 6)) (4.14.0)
# Requirement already satisfied: bleach!=5.0.0 in /home/ppanta/.local/lib/python3.10/site-packages (from bleach[css]!=5.0.0->nbconvert>=7.10->-r requirements.txt (line 6)) (6.2.0)
# Requirement already satisfied: defusedxml in /home/ppanta/.local/lib/python3.10/site-packages (from nbconvert>=7.10->-r requirements.txt (line 6)) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in /home/ppanta/.local/lib/python3.10/site-packages (from nbconvert>=7.10->-r requirements.txt (line 6)) (3.1.6)
# Requirement already satisfied: jupyterlab-pygments in /home/ppanta/.local/lib/python3.10/site-packages (from nbconvert>=7.10->-r requirements.txt (line 6)) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /home/ppanta/.local/lib/python3.10/site-packages (from nbconvert>=7.10->-r requirements.txt (line 6)) (3.0.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in /home/ppanta/.local/lib/python3.10/site-packages (from nbconvert>=7.10->-r requirements.txt (line 6)) (3.1.4)
# Requirement already satisfied: nbclient>=0.5.0 in /home/ppanta/.local/lib/python3.10/site-packages (from nbconvert>=7.10->-r requirements.txt (line 6)) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/ppanta/.local/lib/python3.10/site-packages (from nbconvert>=7.10->-r requirements.txt (line 6)) (1.5.1)
# Requirement already satisfied: pygments>=2.4.1 in /home/ppanta/.local/lib/python3.10/site-packages (from nbconvert>=7.10->-r requirements.txt (line 6)) (2.19.2)
# Requirement already satisfied: typing-extensions in /home/ppanta/.local/lib/python3.10/site-packages (from mistune<4,>=2.0.3->nbconvert>=7.10->-r requirements.txt (line 6)) (4.15.0)
# Requirement already satisfied: comm>=0.1.1 in /home/ppanta/.local/lib/python3.10/site-packages (from ipykernel>=6.29->-r requirements.txt (line 7)) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /home/ppanta/.local/lib/python3.10/site-packages (from ipykernel>=6.29->-r requirements.txt (line 7)) (1.8.17)
# Requirement already satisfied: ipython>=7.23.1 in /home/ppanta/.local/lib/python3.10/site-packages (from ipykernel>=6.29->-r requirements.txt (line 7)) (8.37.0)
# Requirement already satisfied: jupyter-client>=8.0.0 in /home/ppanta/.local/lib/python3.10/site-packages (from ipykernel>=6.29->-r requirements.txt (line 7)) (8.6.3)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/ppanta/.local/lib/python3.10/site-packages (from ipykernel>=6.29->-r requirements.txt (line 7)) (0.1.7)
# Requirement already satisfied: nest-asyncio>=1.4 in /home/ppanta/.local/lib/python3.10/site-packages (from ipykernel>=6.29->-r requirements.txt (line 7)) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in /home/ppanta/.local/lib/python3.10/site-packages (from ipykernel>=6.29->-r requirements.txt (line 7)) (7.1.0)
# Requirement already satisfied: pyzmq>=25 in /home/ppanta/.local/lib/python3.10/site-packages (from ipykernel>=6.29->-r requirements.txt (line 7)) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in /home/ppanta/.local/lib/python3.10/site-packages (from ipykernel>=6.29->-r requirements.txt (line 7)) (6.5.2)
# Requirement already satisfied: async-lru>=1.0.0 in /home/ppanta/.local/lib/python3.10/site-packages (from jupyterlab>=4.2->-r requirements.txt (line 10)) (2.0.5)
# Requirement already satisfied: httpx<1,>=0.25.0 in /home/ppanta/.local/lib/python3.10/site-packages (from jupyterlab>=4.2->-r requirements.txt (line 10)) (0.28.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /home/ppanta/.local/lib/python3.10/site-packages (from jupyterlab>=4.2->-r requirements.txt (line 10)) (2.3.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /home/ppanta/.local/lib/python3.10/site-packages (from jupyterlab>=4.2->-r requirements.txt (line 10)) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /home/ppanta/.local/lib/python3.10/site-packages (from jupyterlab>=4.2->-r requirements.txt (line 10)) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in /home/ppanta/.local/lib/python3.10/site-packages (from jupyterlab>=4.2->-r requirements.txt (line 10)) (0.2.4)
# Requirement already satisfied: setuptools>=41.1.0 in /home/ppanta/.local/lib/python3.10/site-packages (from jupyterlab>=4.2->-r requirements.txt (line 10)) (80.9.0)
# Requirement already satisfied: anyio in /home/ppanta/.local/lib/python3.10/site-packages (from httpx<1,>=0.25.0->jupyterlab>=4.2->-r requirements.txt (line 10)) (4.11.0)
# Requirement already satisfied: certifi in /home/ppanta/.local/lib/python3.10/site-packages (from httpx<1,>=0.25.0->jupyterlab>=4.2->-r requirements.txt (line 10)) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /home/ppanta/.local/lib/python3.10/site-packages (from httpx<1,>=0.25.0->jupyterlab>=4.2->-r requirements.txt (line 10)) (1.0.9)
# Requirement already satisfied: idna in /home/ppanta/.local/lib/python3.10/site-packages (from httpx<1,>=0.25.0->jupyterlab>=4.2->-r requirements.txt (line 10)) (3.10)
# Requirement already satisfied: h11>=0.16 in /home/ppanta/.local/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab>=4.2->-r requirements.txt (line 10)) (0.16.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /home/ppanta/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=4.2->-r requirements.txt (line 10)) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /home/ppanta/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=4.2->-r requirements.txt (line 10)) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /home/ppanta/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=4.2->-r requirements.txt (line 10)) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in /home/ppanta/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=4.2->-r requirements.txt (line 10)) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /home/ppanta/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=4.2->-r requirements.txt (line 10)) (0.23.1)
# Requirement already satisfied: send2trash>=1.8.2 in /home/ppanta/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=4.2->-r requirements.txt (line 10)) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /home/ppanta/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=4.2->-r requirements.txt (line 10)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /home/ppanta/.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=4.2->-r requirements.txt (line 10)) (1.8.0)
# Requirement already satisfied: babel>=2.10 in /home/ppanta/.local/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab>=4.2->-r requirements.txt (line 10)) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in /home/ppanta/.local/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab>=4.2->-r requirements.txt (line 10)) (0.12.1)
# Requirement already satisfied: requests>=2.31 in /home/ppanta/.local/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab>=4.2->-r requirements.txt (line 10)) (2.32.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/ppanta/.local/lib/python3.10/site-packages (from pandas>=2.2->-r requirements.txt (line 16)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./lib/python3.10/site-packages (from pandas>=2.2->-r requirements.txt (line 16)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in ./lib/python3.10/site-packages (from pandas>=2.2->-r requirements.txt (line 16)) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in ./lib/python3.10/site-packages (from matplotlib>=3.8->-r requirements.txt (line 21)) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in ./lib/python3.10/site-packages (from matplotlib>=3.8->-r requirements.txt (line 21)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in ./lib/python3.10/site-packages (from matplotlib>=3.8->-r requirements.txt (line 21)) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./lib/python3.10/site-packages (from matplotlib>=3.8->-r requirements.txt (line 21)) (1.4.9)
# Requirement already satisfied: pillow>=8 in ./lib/python3.10/site-packages (from matplotlib>=3.8->-r requirements.txt (line 21)) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./lib/python3.10/site-packages (from matplotlib>=3.8->-r requirements.txt (line 21)) (3.2.5)
# Requirement already satisfied: joblib>=1.2.0 in ./lib/python3.10/site-packages (from scikit-learn>=1.5->-r requirements.txt (line 25)) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in ./lib/python3.10/site-packages (from scikit-learn>=1.5->-r requirements.txt (line 25)) (3.6.0)
# Requirement already satisfied: graphviz in ./lib/python3.10/site-packages (from catboost>=1.2->-r requirements.txt (line 28)) (0.21)
# Requirement already satisfied: plotly in ./lib/python3.10/site-packages (from catboost>=1.2->-r requirements.txt (line 28)) (6.3.0)
# Requirement already satisfied: six in ./lib/python3.10/site-packages (from catboost>=1.2->-r requirements.txt (line 28)) (1.17.0)
# Requirement already satisfied: tqdm>=4.27.0 in ./lib/python3.10/site-packages (from shap>=0.43->-r requirements.txt (line 29)) (4.67.1)
# Requirement already satisfied: slicer==0.0.8 in ./lib/python3.10/site-packages (from shap>=0.43->-r requirements.txt (line 29)) (0.0.8)
# Requirement already satisfied: numba>=0.54 in ./lib/python3.10/site-packages (from shap>=0.43->-r requirements.txt (line 29)) (0.62.1)
# Requirement already satisfied: cloudpickle in ./lib/python3.10/site-packages (from shap>=0.43->-r requirements.txt (line 29)) (3.1.1)
# Collecting scikit-learn>=1.5 (from -r requirements.txt (line 25))
#   Downloading scikit_learn-1.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Collecting einops<0.9,>=0.2.0 (from tabpfn>=0.1.10->-r requirements.txt (line 33))
#   Downloading einops-0.8.1-py3-none-any.whl.metadata (13 kB)
# Collecting huggingface-hub<1,>=0.0.1 (from tabpfn>=0.1.10->-r requirements.txt (line 33))
#   Downloading huggingface_hub-0.35.3-py3-none-any.whl.metadata (14 kB)
# Collecting pydantic>=2.8.0 (from tabpfn>=0.1.10->-r requirements.txt (line 33))
#   Downloading pydantic-2.11.9-py3-none-any.whl.metadata (68 kB)
# Collecting pydantic-settings>=2.10.1 (from tabpfn>=0.1.10->-r requirements.txt (line 33))
#   Downloading pydantic_settings-2.11.0-py3-none-any.whl.metadata (3.4 kB)
# Collecting eval-type-backport>=0.2.2 (from tabpfn>=0.1.10->-r requirements.txt (line 33))
#   Downloading eval_type_backport-0.2.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting tabpfn-common-utils>=0.1.8 (from tabpfn-common-utils[telemetry-interactive]>=0.1.8->tabpfn>=0.1.10->-r requirements.txt (line 33))
#   Downloading tabpfn_common_utils-0.2.1-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: filelock in /home/ppanta/.local/lib/python3.10/site-packages (from torch>=2.2->-r requirements.txt (line 37)) (3.19.1)
# Collecting networkx (from torch>=2.2->-r requirements.txt (line 37))
#   Downloading networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting fsspec (from torch>=2.2->-r requirements.txt (line 37))
#   Downloading fsspec-2025.9.0-py3-none-any.whl.metadata (10 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=2.2->-r requirements.txt (line 37))
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=2.2->-r requirements.txt (line 37))
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=2.2->-r requirements.txt (line 37))
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=2.2->-r requirements.txt (line 37))
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=2.2->-r requirements.txt (line 37))
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=2.2->-r requirements.txt (line 37))
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=2.2->-r requirements.txt (line 37))
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=2.2->-r requirements.txt (line 37))
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=2.2->-r requirements.txt (line 37))
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparselt-cu12==0.6.2 (from torch>=2.2->-r requirements.txt (line 37))
#   Downloading nvidia_cusparselt_cu12-0.6.2-py3-none-manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting nvidia-nccl-cu12==2.21.5 (from torch>=2.2->-r requirements.txt (line 37))
#   Downloading nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.4.127 (from torch>=2.2->-r requirements.txt (line 37))
#   Downloading nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=2.2->-r requirements.txt (line 37))
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting triton==3.2.0 (from torch>=2.2->-r requirements.txt (line 37))
#   Downloading triton-3.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.4 kB)
# Collecting sympy==1.13.1 (from torch>=2.2->-r requirements.txt (line 37))
#   Downloading sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy==1.13.1->torch>=2.2->-r requirements.txt (line 37))
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting hf-xet<2.0.0,>=1.1.3 (from huggingface-hub<1,>=0.0.1->tabpfn>=0.1.10->-r requirements.txt (line 33))
#   Downloading hf_xet-1.1.10-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.7 kB)
# Requirement already satisfied: daal4py==2024.7.0 in ./lib/python3.10/site-packages (from scikit-learn-intelex->-r requirements.txt (line 47)) (2024.7.0)
# Requirement already satisfied: daal==2024.7.0 in ./lib/python3.10/site-packages (from daal4py==2024.7.0->scikit-learn-intelex->-r requirements.txt (line 47)) (2024.7.0)
# Requirement already satisfied: tbb==2021.* in ./lib/python3.10/site-packages (from daal==2024.7.0->daal4py==2024.7.0->scikit-learn-intelex->-r requirements.txt (line 47)) (2021.13.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/ppanta/.local/lib/python3.10/site-packages (from anyio->httpx<1,>=0.25.0->jupyterlab>=4.2->-r requirements.txt (line 10)) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /home/ppanta/.local/lib/python3.10/site-packages (from anyio->httpx<1,>=0.25.0->jupyterlab>=4.2->-r requirements.txt (line 10)) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in /home/ppanta/.local/lib/python3.10/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab>=4.2->-r requirements.txt (line 10)) (25.1.0)
# Requirement already satisfied: webencodings in /home/ppanta/.local/lib/python3.10/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=7.10->-r requirements.txt (line 6)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /home/ppanta/.local/lib/python3.10/site-packages (from bleach[css]!=5.0.0->nbconvert>=7.10->-r requirements.txt (line 6)) (1.4.0)
# Requirement already satisfied: decorator in ./lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel>=6.29->-r requirements.txt (line 7)) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in /home/ppanta/.local/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel>=6.29->-r requirements.txt (line 7)) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /home/ppanta/.local/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel>=6.29->-r requirements.txt (line 7)) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/ppanta/.local/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel>=6.29->-r requirements.txt (line 7)) (3.0.52)
# Requirement already satisfied: stack_data in /home/ppanta/.local/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel>=6.29->-r requirements.txt (line 7)) (0.6.3)
# Requirement already satisfied: wcwidth in /home/ppanta/.local/lib/python3.10/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel>=6.29->-r requirements.txt (line 7)) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/ppanta/.local/lib/python3.10/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=6.29->-r requirements.txt (line 7)) (0.8.5)
# Requirement already satisfied: attrs>=22.2.0 in /home/ppanta/.local/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=5.9->-r requirements.txt (line 5)) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/ppanta/.local/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=5.9->-r requirements.txt (line 5)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/ppanta/.local/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=5.9->-r requirements.txt (line 5)) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/ppanta/.local/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=5.9->-r requirements.txt (line 5)) (0.27.1)
# Requirement already satisfied: platformdirs>=2.5 in /home/ppanta/.local/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=5.9->-r requirements.txt (line 5)) (4.4.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/ppanta/.local/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.2->-r requirements.txt (line 10)) (3.3.0)
# Requirement already satisfied: rfc3339-validator in /home/ppanta/.local/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.2->-r requirements.txt (line 10)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/ppanta/.local/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.2->-r requirements.txt (line 10)) (0.1.1)
# Requirement already satisfied: fqdn in /home/ppanta/.local/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.2->-r requirements.txt (line 10)) (1.5.1)
# Requirement already satisfied: isoduration in /home/ppanta/.local/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.2->-r requirements.txt (line 10)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /home/ppanta/.local/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.2->-r requirements.txt (line 10)) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /home/ppanta/.local/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.2->-r requirements.txt (line 10)) (1.1.0)
# Requirement already satisfied: uri-template in /home/ppanta/.local/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.2->-r requirements.txt (line 10)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /home/ppanta/.local/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.2->-r requirements.txt (line 10)) (24.11.1)
# Requirement already satisfied: mdurl~=0.1 in /home/ppanta/.local/lib/python3.10/site-packages (from markdown-it-py>=1.0->jupytext>=1.16->-r requirements.txt (line 2)) (0.1.2)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in ./lib/python3.10/site-packages (from numba>=0.54->shap>=0.43->-r requirements.txt (line 29)) (0.45.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/ppanta/.local/lib/python3.10/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel>=6.29->-r requirements.txt (line 7)) (0.7.0)
# Collecting annotated-types>=0.6.0 (from pydantic>=2.8.0->tabpfn>=0.1.10->-r requirements.txt (line 33))
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.2 (from pydantic>=2.8.0->tabpfn>=0.1.10->-r requirements.txt (line 33))
#   Downloading pydantic_core-2.33.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting typing-inspection>=0.4.0 (from pydantic>=2.8.0->tabpfn>=0.1.10->-r requirements.txt (line 33))
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings>=2.10.1->tabpfn>=0.1.10->-r requirements.txt (line 33))
#   Downloading python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/ppanta/.local/lib/python3.10/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab>=4.2->-r requirements.txt (line 10)) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ppanta/.local/lib/python3.10/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab>=4.2->-r requirements.txt (line 10)) (2.5.0)
# Requirement already satisfied: lark>=1.2.2 in /home/ppanta/.local/lib/python3.10/site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.2->-r requirements.txt (line 10)) (1.3.0)
# Collecting posthog~=6.7 (from tabpfn-common-utils>=0.1.8->tabpfn-common-utils[telemetry-interactive]>=0.1.8->tabpfn>=0.1.10->-r requirements.txt (line 33))
#   Downloading posthog-6.7.6-py3-none-any.whl.metadata (6.0 kB)
# Collecting backoff>=1.10.0 (from posthog~=6.7->tabpfn-common-utils>=0.1.8->tabpfn-common-utils[telemetry-interactive]>=0.1.8->tabpfn>=0.1.10->-r requirements.txt (line 33))
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Collecting distro>=1.5.0 (from posthog~=6.7->tabpfn-common-utils>=0.1.8->tabpfn-common-utils[telemetry-interactive]>=0.1.8->tabpfn>=0.1.10->-r requirements.txt (line 33))
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: cffi>=1.0.1 in /home/ppanta/.local/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab>=4.2->-r requirements.txt (line 10)) (2.0.0)
# Requirement already satisfied: pycparser in /home/ppanta/.local/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab>=4.2->-r requirements.txt (line 10)) (2.23)
# Requirement already satisfied: soupsieve>1.2 in /home/ppanta/.local/lib/python3.10/site-packages (from beautifulsoup4->nbconvert>=7.10->-r requirements.txt (line 6)) (2.8)
# Requirement already satisfied: arrow>=0.15.0 in /home/ppanta/.local/lib/python3.10/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.2->-r requirements.txt (line 10)) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /home/ppanta/.local/lib/python3.10/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.2->-r requirements.txt (line 10)) (2.9.0.20250822)
# Requirement already satisfied: narwhals>=1.15.1 in ./lib/python3.10/site-packages (from plotly->catboost>=1.2->-r requirements.txt (line 28)) (2.5.0)
# Requirement already satisfied: executing>=1.2.0 in /home/ppanta/.local/lib/python3.10/site-packages (from stack_data->ipython>=7.23.1->ipykernel>=6.29->-r requirements.txt (line 7)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/ppanta/.local/lib/python3.10/site-packages (from stack_data->ipython>=7.23.1->ipykernel>=6.29->-r requirements.txt (line 7)) (3.0.0)
# Requirement already satisfied: pure-eval in /home/ppanta/.local/lib/python3.10/site-packages (from stack_data->ipython>=7.23.1->ipykernel>=6.29->-r requirements.txt (line 7)) (0.2.3)
# Downloading pytorch_tabnet-4.1.0-py3-none-any.whl (44 kB)
# Downloading tabpfn-2.2.1-py3-none-any.whl (173 kB)
# Downloading scikit_learn-1.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 33.0 MB/s  0:00:00eta 0:00:01
# Downloading torch-2.6.0-cp310-cp310-manylinux1_x86_64.whl (766.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━ 487.1/766.7 MB 3.8 MB/s eta 0:01:14
