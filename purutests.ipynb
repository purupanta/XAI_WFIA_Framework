# %%
# ---- PyTorch (aka "pytorch") ----
import torch
print("Torch:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("GPU count:", torch.cuda.device_count())
# Out:
# Torch: 2.6.0+cu124
# CUDA available: True
# GPU count: 8

# %%
import torch; import shap
from pytorch_tabnet.tab_model import TabNetClassifier
from tabpfn import TabPFNClassifier
print("torch", torch.__version__)
print("tabnet ok", TabNetClassifier is not None)
print("tabpfn ok", TabPFNClassifier is not None)
# Out:
# torch 2.6.0+cu124
# tabnet ok True
# tabpfn ok True

# %%
# 1) Upgrade pip
# !pip install --upgrade pip

# 2) Install PyTorch with CUDA (pick one that matches your driver)
# Example: CUDA 12.1 wheels
# !pip install torch --index-url https://download.pytorch.org/whl/cu121

# 3) TabNet + TabPFN (both use PyTorch and will run on your GPU)
# !pip install pytorch-tabnet tabpfn

# 4) XGBoost (pip wheels may be CPU-only on some platforms)
# !pip install xgboost

# 5) SHAP & friends (if not already)
# !pip install shap scikit-learn matplotlib pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: Error parsing dependencies of distro-info: Invalid version: '0.18ubuntu0.18.04.1'
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://download.pytorch.org/whl/cu121
# ...
# WARNING: Error parsing dependencies of distro-info: Invalid version: '0.18ubuntu0.18.04.1'
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: Error parsing dependencies of distro-info: Invalid version: '0.18ubuntu0.18.04.1'
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: Error parsing dependencies of distro-info: Invalid version: '0.18ubuntu0.18.04.1'
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: Error parsing dependencies of distro-info: Invalid version: '0.18ubuntu0.18.04.1'

# %%
# pip install nvidia-ml-py3
from pynvml import *
nvmlInit()
n = nvmlDeviceGetCount()
for i in range(n):
    h = nvmlDeviceGetHandleByIndex(i)
    name = nvmlDeviceGetName(h).decode()
    util = nvmlDeviceGetUtilizationRates(h)
    mem  = nvmlDeviceGetMemoryInfo(h)
    print(i, name, util.gpu, util.memory, mem.used/1e9, "/", mem.total/1e9, "GB")
# Out:
# 0 NVIDIA GeForce GTX 1080 0 0 8.42039296 / 8.589934592 GB
# 1 NVIDIA GeForce GTX 1080 0 0 0.08421376 / 8.589934592 GB
# 2 NVIDIA GeForce GTX 1080 0 0 0.08421376 / 8.589934592 GB
# 3 NVIDIA GeForce GTX 1080 0 0 0.08421376 / 8.589934592 GB
# 4 NVIDIA GeForce GTX 1080 0 0 0.08421376 / 8.589934592 GB
# 5 NVIDIA GeForce GTX 1080 0 0 0.08421376 / 8.589934592 GB
# 6 NVIDIA GeForce GTX 1080 0 0 0.08421376 / 8.589934592 GB
# 7 NVIDIA GeForce GTX 1080 0 0 0.08421376 / 8.589934592 GB

# %%
# choose one that matches your system; cu121 works on recent drivers
# !pip install --upgrade pip
# !pip install torch --index-url https://download.pytorch.org/whl/cu121
# !pip install xgboost pytorch-tabnet tabpfn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: Error parsing dependencies of distro-info: Invalid version: '0.18ubuntu0.18.04.1'
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://download.pytorch.org/whl/cu121
# ...
# WARNING: Error parsing dependencies of distro-info: Invalid version: '0.18ubuntu0.18.04.1'
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: Error parsing dependencies of distro-info: Invalid version: '0.18ubuntu0.18.04.1'

# %%
# ---- TensorFlow ----
import tensorflow as tf
print("TF:", tf.__version__)
print("TF GPUs:", tf.config.list_physical_devices('GPU'))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 # ---- TensorFlow ----
# ----> 2 import tensorflow as tf
#       3 print("TF:", tf.__version__)
#       4 print("TF GPUs:", tf.config.list_physical_devices('GPU'))
#
# ModuleNotFoundError: No module named 'tensorflow'
